# %% [markdown]
# import pandas as pd
# import numpy as np
# import math

# %%
data = pd.read_csv('data-logistic.csv',header=None)

# %%
data
# Out:
#      0         1          2
# 0   -1 -0.663827  -0.138526
# 1    1  1.994596   2.468025
# 2   -1 -1.247395   0.749425
# 3    1  2.309374   1.899836
# 4    1  0.849143   2.407750
# ..  ..       ...        ...
# 200  1  4.245176   3.053931
# 201  1  2.437935   1.357804
# 202 -1 -1.876638   1.533398
# 203  1 -6.824446 -13.934211
# 204 -1  0.001805   0.865147
#
# [205 rows x 3 columns]

# %%
X = data.iloc[:,1:]

# %%
y = data.iloc[:,:1]
import math

# %%
X
# Out:
#             1          2
# 0   -0.663827  -0.138526
# 1    1.994596   2.468025
# 2   -1.247395   0.749425
# 3    2.309374   1.899836
# 4    0.849143   2.407750
# ..        ...        ...
# 200  4.245176   3.053931
# 201  2.437935   1.357804
# 202 -1.876638   1.533398
# 203 -6.824446 -13.934211
# 204  0.001805   0.865147
#
# [205 rows x 2 columns]

# %%
y
# Out:
#      0
# 0   -1
# 1    1
# 2   -1
# 3    1
# 4    1
# ..  ..
# 200  1
# 201  1
# 202 -1
# 203  1
# 204 -1
#
# [205 rows x 1 columns]

# %%
def fw1(w1, w2, y, X, k, C):
    l = len(y)
    S = 0
    for i in range(0, l):
        S += y[i] * X[1][i] * (1.0 - 1.0 / (1.0 + np.exp(-y[i] * (w1*X[1][i] + w2*X[2][i]))))

    return w1 + (k * (1.0 / l) * S) - k * C * w1


def fw2(w1, w2, y, X, k, C):
    l = len(y)
    S = 0
    for i in range(0, l):
        S += y[i] * X[2][i] * (1.0 - 1.0 / (1.0 + np.exp(-y[i] * (w1*X[1][i] + w2*X[2][i]))))

    return w2 + (k * (1.0 / l) * S) - k * C * w2


# 3. Реализуйте градиентный спуск для обычной и L2-регуляризованной (с коэффициентом регуляризации 10)
# логистической регрессии. Используйте длину шага k=0.1. В качестве начального приближения используйте вектор (0, 0).

def grad(y, X, C, w1=0.0, w2=0.0, k=0.1, delta=1e-6):
    i = 0
    i_max = 10000
    
    while i < i_max:
        i += 1
        print (i)
        
        w1_new, w2_new = fw1(w1, w2, y, X, k, C), fw2(w1, w2, y, X, k, C)
        e = np.sqrt((w1_new - w1) ** 2 + (w2_new - w2) ** 2)

        if e <= delta:
            break
        w1, w2 = w1_new, w2_new

    return w1_new, w2_new

# 4. Запустите градиентный спуск и доведите до сходимости (евклидово расстояние между векторами весов на соседних
# итерациях должно быть не больше 1e-5). Рекомендуется ограничить сверху число итераций десятью тысячами.

w1, w2 = grad(y, X, 0.0)
rw1, rw2 = grad(y, X, 10.0)
# Out:
# 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-bd3e092f7869> in <module>
# ...

# %%
def fw2(w1, w2, y, X, k, C):
    l = len(y)
    S = 0
    for i in range(0, l):
        S += y[i] * X[2][i] * (1.0 - 1.0 / (1.0 + math.exp(-y[i] * (w1*X[1][i] + w2*X[2][i]))))

    return w2 + (k * (1.0 / l) * S) - k * C * w2

# %%
def grad(y, X, C, w1=0.0, w2=0.0, k=0.1, delta=1e-6):
    i = 0
    i_max = 10000
    
    while i < i_max:
        i += 1
        print (i)
        
        w1_new, w2_new = fw1(w1, w2, y, X, k, C), fw2(w1, w2, y, X, k, C)
        e = math.sqrt((w1_new - w1) ** 2 + (w2_new - w2) ** 2)

        if e <= delta:
            break
        w1, w2 = w1_new, w2_new

    return w1_new, w2_new

# %%
a = 1e-6

# %%
a==1/1000000
# Out:
# True

# %%
w1, w2 = grad(y, X, 0.0)
rw1, rw2 = grad(y, X, 10.0)
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-80cafb30a67c> in <module>
# ----> 1 w1, w2 = grad(y, X, 0.0)
#       2 rw1, rw2 = grad(y, X, 10.0)
#
# <ipython-input-38-72cafbaed0d2> in grad(y, X, C, w1, w2, k, delta)
#       7         print (i)
#       8
# ----> 9         w1_new, w2_new = fw1(w1, w2, y, X, k, C), fw2(w1, w2, y, X, k, C)
#      10         e = math.sqrt((w1_new - w1) ** 2 + (w2_new - w2) ** 2)
#      11
#
# <ipython-input-36-e983d805ab29> in fw1(w1, w2, y, X, k, C)
#       3     S = 0
#       4     for i in range(0, l):
# ----> 5         S += y[i] * X[1][i] * (1.0 - 1.0 / (1.0 + math.exp(-y[i] * (w1*X[1][i] + w2*X[2][i]))))
#       6
#       7     return w1 + (k * (1.0 / l) * S) - k * C * w1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     129         if len(self) == 1:
# ...

# %%
data_class = pd.read_csv('tion.csv')

# %%
data_class
# Out:
#      true  pred
# 0       1     0
# 1       1     1
# 2       1     1
# 3       0     0
# 4       1     1
# ..    ...   ...
# 195     0     0
# 196     0     0
# 197     1     0
# 198     0     1
# 199     0     0
#
# [200 rows x 2 columns]

# %%
x = data_class.iloc[:,1:]

# %%
y = data_class.iloc[:,:1]

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6fcf9dfbd479> in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
x.loc[5]
# Out:
# pred    1
# Name: 5, dtype: int64

# %%
x = np.array(x)

# %%
x[2]
# Out:
# array([1], dtype=int64)

# %%
# Out:
# array([[0]], dtype=int64)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-be36184be6bd> in <module>
#       1 for i in range(len(x)):
# ----> 2     if x.loc[i] == y.loc[i]:
#       3         print(1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1140
#    1141         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1142             raise ValueError("Can only compare identically-labeled " "Series objects")
#    1143
#    1144         elif is_categorical_dtype(self):
#
# ValueError: Can only compare identically-labeled Series objects

# %%
data = data_class

# %%
np.array(data.loc[0].true)
# Out:
# array(1, dtype=int64)

# %%
np.array(data.loc[0].true) == np.array(data.loc[0].pred)
# Out:
# False

# %%
np.array(data.loc[0].true)==1
# Out:
# True

# %%
tp,tn,fp,fn = 0,0,0,0
for i in range(len(x)):
    if np.array(data.loc[i].true)==1 and np.array(data.loc[i].pred)==1:
        tp+=1
    if np.array(data.loc[i].true)==1 and np.array(data.loc[i].pred)==0:
        tn+=1
    if np.array(data.loc[i].true)==0 and np.array(data.loc[i].pred)==1:
        fp+=1
    if np.array(data.loc[i].true)==0 and np.array(data.loc[i].pred)==0:
        fn+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-59c426096460> in <module>
#       1 tp,tn,fp,fn = 0,0,0,0
# ----> 2 for i in range(len(x)):
#       3     if np.array(data.loc[i].true)==1 and np.array(data.loc[i].pred)==1:
#       4         tp+=1
#       5     if np.array(data.loc[i].true)==1 and np.array(data.loc[i].pred)==0:
#
# NameError: name 'x' is not defined

# %%
print(tp,fp,fn,tn)
# Out:
# 43 59 64 34

# %%
clf_table = {'tp': (1, 1), 'fp': (0, 1), 'fn': (1, 0), 'tn': (0, 0)}
for name, res in clf_table.items():
    clf_table[name] = len(data[(data['true'] == res[0]) & (data['pred'] == res[1])])

print(1, '{tp} {fp} {fn} {tn}'.format(**clf_table))

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# 1 43 34 59 64

# %%
a_s = accuracy_score(y,x)

# %%
a_s
# Out:
# 0.535

# %%
p_s,r_s,f_s = precision_score(y,x), recall_score(y,x), f1_score(y,x)

# %%
print(a_s,p_s,r_s,f_s)
# Out:
# 0.535 0.5584415584415584 0.4215686274509804 0.48044692737430167

# %%
data_2 = pd.read_csv('scores.csv')

# %%
data_2
# Out:
#      true  score_logreg  score_svm  score_knn  score_tree
# 0       0      0.683832   0.145976   0.787063    0.500000
# 1       1      0.801966   0.239511   1.000000    0.833333
# 2       0      0.382315  -0.245701   0.000000    0.000000
# 3       1      0.506797  -0.137058   0.000000    0.105263
# 4       1      0.488781  -0.154148   0.000000    0.105263
# ..    ...           ...        ...        ...         ...
# 195     0      0.573801  -0.088203   0.284192    0.400000
# 196     0      0.624422  -0.012315   0.205437    0.400000
# 197     1      0.425538  -0.135673   0.382351    0.700000
# 198     0      0.905270   0.583806   1.000000    1.000000
# 199     0      0.275594  -0.422160   0.743567    0.642857
#
# [200 rows x 5 columns]

# %%
from sklearn.metrics import roc_auc_score as ras

# %%
y = data_2.iloc[:,:1]

# %%
y
# Out:
#      true
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
# ..    ...
# 195     0
# 196     0
# 197     1
# 198     0
# 199     0
#
# [200 rows x 1 columns]

# %%
for i in range(4):
    print(ras(y,data_2.iloc[:,i+1:i+2]))
# Out:
# 0.719187675070028
# 0.7086834733893557
# 0.6351540616246498
# 0.6919267707082833

# %%
score_log, score_svm, score_knn, score_tree = 0.719187675070028, 0.7086834733893557, 0.6351540616246498, 0.6919267707082833

# %% [raw]
# score_log

# %%
y
# Out:
#      true
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
# ..    ...
# 195     0
# 196     0
# 197     1
# 198     0
# 199     0
#
# [200 rows x 1 columns]

# %%
score_log
# Out:
# 0.719187675070028

# %%
from sklearn.metrics import precision_recall_curve as prc

# %%
for i in range(4):
    print(prc(y,data_2.iloc[:,i+1:i+2]))
# Out:
# (array([0.49746193, 0.49489796, 0.49230769, 0.49484536, 0.49740933,
#        0.49479167, 0.4973822 , 0.49473684, 0.4973545 , 0.5       ,
#        0.5026738 , 0.5       , 0.4972973 , 0.5       , 0.50273224,
#        0.50549451, 0.50828729, 0.51111111, 0.51396648, 0.51685393,
#        0.51977401, 0.52272727, 0.52571429, 0.52873563, 0.53179191,
#        0.53488372, 0.5380117 , 0.53529412, 0.53846154, 0.54166667,
#        0.54491018, 0.54819277, 0.55151515, 0.54878049, 0.55214724,
#        0.54938272, 0.55279503, 0.55625   , 0.55974843, 0.55696203,
#        0.56050955, 0.56410256, 0.56129032, 0.56493506, 0.56862745,
#        0.56578947, 0.56953642, 0.56666667, 0.5704698 , 0.57432432,
#        0.57142857, 0.57534247, 0.57241379, 0.57638889, 0.58041958,
#        0.58450704, 0.58156028, 0.58571429, 0.58992806, 0.58695652,
#        0.59124088, 0.59558824, 0.6       , 0.59701493, 0.60150376,
#        0.60606061, 0.60305344, 0.6       , 0.60465116, 0.609375  ,
# ...

# %%
import pandas as pd
import numpy as np
import math

# %%
data_salary = pd.read_csv('salary-train.csv')

# %%
data_salary
# Out:
#                                          FullDescription LocationNormalized  \
# 0      International Sales Manager London ****k  ****...             London
# 1      An ideal opportunity for an individual that ha...             London
# 2      Online Content and Brand Manager// Luxury Reta...  South East London
# 3      A great local marketleader is seeking a perman...            Dereham
# 4      Registered Nurse / RGN  Nursing Home for Young...   Sutton Coldfield
# ...                                                  ...                ...
# 59995  As a result of continued growth, First Class S...        Whitley Bay
# 59996  PHP / MVC Web Developer  MacclesfieldCirca ***...       Macclesfield
# 59997  Staff Nurse, Nursing Home, Baldock White Recru...            Baldock
# 59998  This is one of the best agency side opportunit...           The City
# 59999  Must have CSCS card must have asbestos awarene...             London
#
#       ContractTime  SalaryNormalized
# ...

# %%
data_salary_np = data_salary['FullDescription']

# %%
for i in range(59999):
    data_salary_lower = data_salary.loc[i,'FullDescription'].lower()

# %%
data_salary_lower
# Out:
# "this is one of the best agency side opportunities seen in a long time as you will have the opportunity to direct this agency's flaghship client  one of the uk's largest online shopping retailers  selling 53 million items annually. the perfect candidate will have 5**** years of experience and be currently at ecommerce manager or director level in a large scale, multimillion pound ecommerce retailer. you will also have management experience of circa 10 people and be particularly strong on ppc, seo, affiliates, display, dsps and dmps, product feeds, mobile and email marketing. your remit will be to ensure delivery, growth and profitable results for the client, whilst driving forward innovation in strategic thinking. it requires a combination of very proficient operational skills and sophisticated planning. in conjunction to the client you will be required to contribute to team and product development. this will include training, learning and development and career progression of our pe
# ...

# %%
X_train = pd.read_csv('salary-train.csv')

# %%
X_train
# Out:
#                                          FullDescription LocationNormalized  \
# 0      International Sales Manager London ****k  ****...             London
# 1      An ideal opportunity for an individual that ha...             London
# 2      Online Content and Brand Manager// Luxury Reta...  South East London
# 3      A great local marketleader is seeking a perman...            Dereham
# 4      Registered Nurse / RGN  Nursing Home for Young...   Sutton Coldfield
# ...                                                  ...                ...
# 59995  As a result of continued growth, First Class S...        Whitley Bay
# 59996  PHP / MVC Web Developer  MacclesfieldCirca ***...       Macclesfield
# 59997  Staff Nurse, Nursing Home, Baldock White Recru...            Baldock
# 59998  This is one of the best agency side opportunit...           The City
# 59999  Must have CSCS card must have asbestos awarene...             London
#
#       ContractTime  SalaryNormalized
# ...

# %%
X_test = pd.read_csv('salary-test-mini.csv')

# %%
X_test
# Out:
#                                      FullDescription LocationNormalized  \
# 0  We currently have a vacancy for an HR Project ...      Milton Keynes
# 1  A Web developer opportunity has arisen with an...         Manchester
#
#   ContractTime  SalaryNormalized
# 0     contract               NaN
# 1    permanent               NaN

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-e983f374794d> in <module>
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
X_train
# Out:
#                                          FullDescription LocationNormalized  \
# 0      International Sales Manager London ****k  ****...             London
# 1      An ideal opportunity for an individual that ha...             London
# 2      Online Content and Brand Manager// Luxury Reta...  South East London
# 3      A great local marketleader is seeking a perman...            Dereham
# 4      Registered Nurse / RGN  Nursing Home for Young...   Sutton Coldfield
# ...                                                  ...                ...
# 59995  As a result of continued growth, First Class S...        Whitley Bay
# 59996  PHP / MVC Web Developer  MacclesfieldCirca ***...       Macclesfield
# 59997  Staff Nurse, Nursing Home, Baldock White Recru...            Baldock
# 59998  This is one of the best agency side opportunit...           The City
# 59999  Must have CSCS card must have asbestos awarene...             London
#
#       ContractTime  SalaryNormalized
# ...

# %%
y_train = X_train['SalaryNormalized']

# %%
X_train = X_train[['FullDescription','LocationNormalized','ContractTime']]

# %%
y_train
# Out:
# 0        33000
# 1        50000
# 2        40000
# 3        22500
# 4        20355
#          ...
# 59995    26400
# 59996    26000
# 59997    24500
# 59998    65000
# 59999    23040
# Name: SalaryNormalized, Length: 60000, dtype: int64

# %%
X_train['FullDescription'] = X_train['FullDescription'].replace('[^a-zA-Z0-9]', '', regex = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train['FullDescription']
# Out:
# 0        InternationalSalesManagerLondonkkUncappedCommi...
# 1        Anidealopportunityforanindividualthathasgained...
# 2        OnlineContentandBrandManagerLuxuryRetailUptokI...
# 3        AgreatlocalmarketleaderisseekingapermanentPayr...
# 4        RegisteredNurseRGNNursingHomeforYoungAdultsLoc...
#                                ...
# 59995    AsaresultofcontinuedgrowthFirstClassSupplyandT...
# 59996    PHPMVCWebDeveloperMacclesfieldCircaperannumPHP...
# 59997    StaffNurseNursingHomeBaldockWhiteRecruitmentis...
# 59998    Thisisoneofthebestagencysideopportunitiesseeni...
# 59999    MusthaveCSCScardmusthaveasbestosawarenesscerti...
# Name: FullDescription, Length: 60000, dtype: object

# %%
X_train['LocationNormalized'].fillna('nan')
# Out:
# 0                   London
# 1                   London
# 2        South East London
# 3                  Dereham
# 4         Sutton Coldfield
#                ...
# 59995          Whitley Bay
# 59996         Macclesfield
# 59997              Baldock
# 59998             The City
# 59999               London
# Name: LocationNormalized, Length: 60000, dtype: object

# %%
for i in range(1000):
    print(X_train['ContractTime'][i])
# Out:
# permanent
# permanent
# permanent
# permanent
# nan
# nan
# permanent
# permanent
# permanent
# permanent
# contract
# permanent
# permanent
# permanent
# nan
# permanent
# contract
# permanent
# nan
# nan
# permanent
# permanent
# permanent
# contract
# nan
# permanent
# permanent
# permanent
# permanent
# permanent
# nan
# permanent
# contract
# permanent
# nan
# nan
# nan
# permanent
# permanent
# permanent
# nan
# contract
# nan
# contract
# nan
# permanent
# permanent
# contract
# permanent
# permanent
# permanent
# nan
# permanent
# nan
# permanent
# permanent
# nan
# nan
# nan
# permanent
# contract
# permanent
# nan
# contract
# permanent
# permanent
# permanent
# nan
# contract
# permanent
# permanent
# permanent
# permanent
# permanent
# contract
# contract
# permanent
# permanent
# permanent
# contract
# nan
# nan
# nan
# nan
# permanent
# contract
# nan
# permanent
# nan
# contract
# nan
# nan
# permanent
# permanent
# permanent
# permanent
# permanent
# nan
# nan
# nan
# ...

# %%
X_train['ContractTime'].fillna('nan', inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
for i in range(1000):
    print(X_train['ContractTime'][i])
# Out:
# permanent
# permanent
# permanent
# permanent
# nan
# nan
# permanent
# permanent
# permanent
# permanent
# contract
# permanent
# permanent
# permanent
# nan
# permanent
# contract
# permanent
# nan
# nan
# permanent
# permanent
# permanent
# contract
# nan
# permanent
# permanent
# permanent
# permanent
# permanent
# nan
# permanent
# contract
# permanent
# nan
# nan
# nan
# permanent
# permanent
# permanent
# nan
# contract
# nan
# contract
# nan
# permanent
# permanent
# contract
# permanent
# permanent
# permanent
# nan
# permanent
# nan
# permanent
# permanent
# nan
# nan
# nan
# permanent
# contract
# permanent
# nan
# contract
# permanent
# permanent
# permanent
# nan
# contract
# permanent
# permanent
# permanent
# permanent
# permanent
# contract
# contract
# permanent
# permanent
# permanent
# contract
# nan
# nan
# nan
# nan
# permanent
# contract
# nan
# permanent
# nan
# contract
# nan
# nan
# permanent
# permanent
# permanent
# permanent
# permanent
# nan
# nan
# nan
# ...

# %%
X_train['LocationNormalized'].fillna('nan', inplace=True)
X_train['ContractTime'].fillna('nan', inplace=True)

# %%
X_train['FullDescription'] = X_train['FullDescription'].str.lower()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train['FullDescription']
# Out:
# 0        internationalsalesmanagerlondonkkuncappedcommi...
# 1        anidealopportunityforanindividualthathasgained...
# 2        onlinecontentandbrandmanagerluxuryretailuptoki...
# 3        agreatlocalmarketleaderisseekingapermanentpayr...
# 4        registerednursergnnursinghomeforyoungadultsloc...
#                                ...
# 59995    asaresultofcontinuedgrowthfirstclasssupplyandt...
# 59996    phpmvcwebdevelopermacclesfieldcircaperannumphp...
# 59997    staffnursenursinghomebaldockwhiterecruitmentis...
# 59998    thisisoneofthebestagencysideopportunitiesseeni...
# 59999    musthavecscscardmusthaveasbestosawarenesscerti...
# Name: FullDescription, Length: 60000, dtype: object

# %%
X_train
# Out:
#                                          FullDescription LocationNormalized  \
# 0      internationalsalesmanagerlondonkkuncappedcommi...             London
# 1      anidealopportunityforanindividualthathasgained...             London
# 2      onlinecontentandbrandmanagerluxuryretailuptoki...  South East London
# 3      agreatlocalmarketleaderisseekingapermanentpayr...            Dereham
# 4      registerednursergnnursinghomeforyoungadultsloc...   Sutton Coldfield
# ...                                                  ...                ...
# 59995  asaresultofcontinuedgrowthfirstclasssupplyandt...        Whitley Bay
# 59996  phpmvcwebdevelopermacclesfieldcircaperannumphp...       Macclesfield
# 59997  staffnursenursinghomebaldockwhiterecruitmentis...            Baldock
# 59998  thisisoneofthebestagencysideopportunitiesseeni...           The City
# 59999  musthavecscscardmusthaveasbestosawarenesscerti...             London
#
#       ContractTime
# 0        permanent
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
TfidfVectorizer()
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=1, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
vectorizer = TfidfVectorizer(min_df=4)
X_test
# Out:
#                                      FullDescription LocationNormalized  \
# 0  We currently have a vacancy for an HR Project ...      Milton Keynes
# 1  A Web developer opportunity has arisen with an...         Manchester
#
#   ContractTime  SalaryNormalized
# 0     contract               NaN
# 1    permanent               NaN

# %%
X_train_vec = vectorizer.fit_transform(X_train['FullDescription'])

# %%
X_test_vec = vectorizer.transform(X_test['FullDescription'])

# %%
from sklearn.feature_extraction import DictVectorizer
enc = DictVectorizer()
X_train_categ = enc.fit_transform(X_train[['LocationNormalized', 'ContractTime']].to_dict('records'))
X_test_categ = enc.transform(X_test[['LocationNormalized', 'ContractTime']].to_dict('records'))

# %%
print(X_train_categ)
# Out:
#   (0, 2)	1.0
#   (0, 957)	1.0
#   (1, 2)	1.0
#   (1, 957)	1.0
#   (2, 2)	1.0
#   (2, 1392)	1.0
#   (3, 2)	1.0
#   (3, 471)	1.0
#   (4, 1)	1.0
#   (4, 1495)	1.0
#   (5, 1)	1.0
#   (5, 422)	1.0
#   (6, 2)	1.0
#   (6, 1575)	1.0
#   (7, 2)	1.0
#   (7, 224)	1.0
#   (8, 2)	1.0
#   (8, 309)	1.0
#   (9, 2)	1.0
#   (9, 1392)	1.0
#   (10, 0)	1.0
#   (10, 86)	1.0
#   (11, 2)	1.0
#   (11, 639)	1.0
#   (12, 2)	1.0
#   :	:
#   (59987, 1411)	1.0
#   (59988, 1)	1.0
#   (59988, 335)	1.0
#   (59989, 2)	1.0
#   (59989, 899)	1.0
#   (59990, 2)	1.0
#   (59990, 44)	1.0
#   (59991, 2)	1.0
#   (59991, 1665)	1.0
#   (59992, 0)	1.0
#   (59992, 957)	1.0
#   (59993, 1)	1.0
#   (59993, 957)	1.0
#   (59994, 1)	1.0
#   (59994, 679)	1.0
#   (59995, 0)	1.0
#   (59995, 1691)	1.0
#   (59996, 2)	1.0
#   (59996, 986)	1.0
#   (59997, 1)	1.0
#   (59997, 78)	1.0
#   (59998, 2)	1.0
#   (59998, 1531)	1.0
#   (59999, 1)	1.0
#   (59999, 957)	1.0

# %%
X_test_vec
import scipy

# %%
X_train_f = scipy.sparse.hstack([X_train_vec, X_train_categ])

# %%
X_test_f = scipy.sparse.hstack([X_test_vec, X_test_categ])

# %%
X_test_f
# Out:
# <2x1767 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4 stored elements in COOrdinate format>

# %%
print(X_train_f)
# Out:
#   (6537, 0)	1.0
#   (6810, 0)	1.0
#   (43129, 0)	1.0
#   (48509, 0)	1.0
#   (0, 3)	1.0
#   (0, 958)	1.0
#   (1, 3)	1.0
#   (1, 958)	1.0
#   (2, 3)	1.0
#   (2, 1393)	1.0
#   (3, 3)	1.0
#   (3, 472)	1.0
#   (4, 2)	1.0
#   (4, 1496)	1.0
#   (5, 2)	1.0
#   (5, 423)	1.0
#   (6, 3)	1.0
#   (6, 1576)	1.0
#   (7, 3)	1.0
#   (7, 225)	1.0
#   (8, 3)	1.0
#   (8, 310)	1.0
#   (9, 3)	1.0
#   (9, 1393)	1.0
#   (10, 1)	1.0
#   :	:
#   (59987, 1412)	1.0
#   (59988, 2)	1.0
#   (59988, 336)	1.0
#   (59989, 3)	1.0
#   (59989, 900)	1.0
#   (59990, 3)	1.0
#   (59990, 45)	1.0
#   (59991, 3)	1.0
#   (59991, 1666)	1.0
#   (59992, 1)	1.0
#   (59992, 958)	1.0
#   (59993, 2)	1.0
#   (59993, 958)	1.0
#   (59994, 2)	1.0
#   (59994, 680)	1.0
#   (59995, 1)	1.0
#   (59995, 1692)	1.0
#   (59996, 3)	1.0
#   (59996, 987)	1.0
#   (59997, 2)	1.0
#   (59997, 79)	1.0
#   (59998, 3)	1.0
#   (59998, 1532)	1.0
#   (59999, 2)	1.0
#   (59999, 958)	1.0

# %%
from sklearn.linear_model import Ridge

# %%
clf = Ridge(alpha=1, fit_intercept=False, solver='lsqr',random_state=241)

# %%
clf()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-175-7246e647868c> in <module>
# ----> 1 clf()
#
# TypeError: 'Ridge' object is not callable

# %%
y = X_test['SalaryNormalized']
X_test
# Out:
#                                      FullDescription LocationNormalized  \
# 0  We currently have a vacancy for an HR Project ...      Milton Keynes
# 1  A Web developer opportunity has arisen with an...         Manchester
#
#   ContractTime  SalaryNormalized
# 0     contract               NaN
# 1    permanent               NaN

# %%
clf.fit(X_train_f,y_train)
# Out:
# Ridge(alpha=1, copy_X=True, fit_intercept=False, max_iter=None, normalize=False,
#       random_state=241, solver='lsqr', tol=0.001)

# %%
res = clf.predict(X_test_f)

# %%
res
# Out:
# array([33438.23445686, 31509.34670717])

# %%
result = np.round(res, 2)

# %%
result
# Out:
# array([33438.23, 31509.35])

# %%
data = pd.read_csv('prices.csv')

# %%
data
# Out:
#            date        AXP          BA        CAT       CSCO         CVX  \
# 0    2013-09-23  76.440002  117.510002  85.029999  24.270000  125.519997
# 1    2013-09-24  76.070000  119.000000  85.110001  24.139999  124.489998
# 2    2013-09-25  75.989998  118.510002  84.500000  24.430000  124.070000
# 3    2013-09-26  76.320000  119.379997  84.199997  23.770000  123.489998
# 4    2013-09-27  75.889999  118.739998  83.800003  23.330000  122.639999
# ..          ...        ...         ...        ...        ...         ...
# 369  2015-03-12  81.559998  152.039993  80.190002  28.240000  102.419998
# 370  2015-03-13  80.599998  151.570007  79.230003  27.940001  101.620003
# 371  2015-03-16  81.500000  153.669998  79.970001  28.299999  103.129997
# 372  2015-03-17  81.059998  154.509995  78.449997  28.150000  103.169998
# 373  2015-03-18  81.860001  155.729996  81.330002  28.150000  106.699997
#
#             DD         DIS         GE          GS  ...        PFE         PG  \
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=10)

# %%
pca(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-230-16cbf101227f> in <module>
# ----> 1 pca(data)
#
# TypeError: 'PCA' object is not callable

# %%
pca.fit(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-231-1a871a404438> in <module>
# ----> 1 pca.fit(data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in fit(self, X, y)
#     339             Returns the instance itself.
#     340         """
# --> 341         self._fit(X)
#     342         return self
#     343
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in _fit(self, X)
#     380
#     381         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 382                         copy=self.copy)
#     383
#     384         # Handle n_components==None
#
# ...

# %%
data_main = data.iloc[:,1:]

# %%
data_main = np.array(data_main)

# %%
pca.fit(data_main)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.explained_variance_
# Out:
# array([1522.30984761,  226.75203269,  102.90079304,   59.22448474,
#          45.63910225,   39.79124256,   13.90224179,   12.65051773,
#           6.6043666 ,    6.29570803])

# %%
count = 0
sum = 0
for i in range(len(pca.explained_variance_ratio_)):
    count+=1
    value = pca.explained_variance_ratio_[i]
    sum+= value
    if sum > 0.9:
        break

# %%
count
# Out:
# 4

# %%
pca.explained_variance_ratio_
# Out:
# array([0.73897118, 0.11007169, 0.04995088, 0.0287492 , 0.02215448,
#        0.01931577, 0.00674853, 0.00614091, 0.00320594, 0.00305611])

# %%
pca.components_
# Out:
# array([[ 1.61383840e-02,  1.20644923e-01, -5.16612711e-02,
#          5.04842369e-02, -1.25859933e-01,  1.14089567e-01,
#          2.33906290e-01, -6.20513749e-03,  2.51227032e-01,
#          2.88996029e-01, -2.64998795e-01,  9.31320168e-02,
#          9.13948403e-02,  4.69879340e-02,  2.90549417e-02,
#         -2.61068828e-02,  3.29615584e-01,  7.13897133e-02,
#          7.62295699e-02,  2.11888868e-01,  2.30922941e-02,
#          7.77316954e-02, -7.20594590e-03,  1.89479745e-01,
#          3.21564017e-01,  5.36834873e-02,  5.79683946e-01,
#          1.09122230e-04,  8.71614334e-02, -4.29421420e-02],
#        [-2.33025791e-01,  1.38102207e-01, -5.64736227e-01,
#         -2.94213771e-02, -2.97156167e-01, -7.00723638e-02,
#         -2.41633004e-01, -2.26028350e-02, -1.05527180e-01,
#          3.16032026e-02, -3.56926513e-01, -1.51980885e-01,
#         -2.76101639e-01, -6.73887479e-02, -5.03438625e-02,
#         -5.87043804e-02, -2.17410195e-01, -1.90769246e-01,
# ...

# %%
f_c = pd.DataFrame(pca.transform(data_main)[:,0])

# %%
f_c
# Out:
#              0
# 0   -50.902404
# 1   -52.846909
# 2   -54.614439
# 3   -52.600566
# 4   -52.370123
# ..         ...
# 369  81.290980
# 370  77.903534
# 371  83.798199
# 372  79.195789
# 373  82.968859
#
# [374 rows x 1 columns]

# %%
data_index = pd.read_csv('djia_index.csv')

# %%
data_index
# Out:
#            date          ^DJI
# 0    2013-09-23  15401.379883
# 1    2013-09-24  15334.589844
# 2    2013-09-25  15273.259766
# 3    2013-09-26  15328.299805
# 4    2013-09-27  15258.240234
# ..          ...           ...
# 369  2015-03-12  17895.220703
# 370  2015-03-13  17749.310547
# 371  2015-03-16  17977.419922
# 372  2015-03-17  17849.080078
# 373  2015-03-18  18076.189453
#
# [374 rows x 2 columns]

# %%
data_index_main = data_index.iloc[:,1:]

# %%
data_index_main
# Out:
#              ^DJI
# 0    15401.379883
# 1    15334.589844
# 2    15273.259766
# 3    15328.299805
# 4    15258.240234
# ..            ...
# 369  17895.220703
# 370  17749.310547
# 371  17977.419922
# 372  17849.080078
# 373  18076.189453
#
# [374 rows x 1 columns]

# %%
np
# Out:
# <module 'numpy' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>

# %%
coef = np.corrcoef(f_c.T, data_index_main.T)[1,0]
print("Corrcoef %0.2f" % coef)
# Out:
# Corrcoef 0.91

# %%
data
# Out:
#            date        AXP          BA        CAT       CSCO         CVX  \
# 0    2013-09-23  76.440002  117.510002  85.029999  24.270000  125.519997
# 1    2013-09-24  76.070000  119.000000  85.110001  24.139999  124.489998
# 2    2013-09-25  75.989998  118.510002  84.500000  24.430000  124.070000
# 3    2013-09-26  76.320000  119.379997  84.199997  23.770000  123.489998
# 4    2013-09-27  75.889999  118.739998  83.800003  23.330000  122.639999
# ..          ...        ...         ...        ...        ...         ...
# 369  2015-03-12  81.559998  152.039993  80.190002  28.240000  102.419998
# 370  2015-03-13  80.599998  151.570007  79.230003  27.940001  101.620003
# 371  2015-03-16  81.500000  153.669998  79.970001  28.299999  103.129997
# 372  2015-03-17  81.059998  154.509995  78.449997  28.150000  103.169998
# 373  2015-03-18  81.860001  155.729996  81.330002  28.150000  106.699997
#
#             DD         DIS         GE          GS  ...        PFE         PG  \
# ...

# %%
data_main
# Out:
#            AXP          BA        CAT       CSCO         CVX         DD  \
# 0    76.440002  117.510002  85.029999  24.270000  125.519997  59.409999
# 1    76.070000  119.000000  85.110001  24.139999  124.489998  59.319997
# 2    75.989998  118.510002  84.500000  24.430000  124.070000  59.319997
# 3    76.320000  119.379997  84.199997  23.770000  123.489998  59.509996
# 4    75.889999  118.739998  83.800003  23.330000  122.639999  59.009995
# ..         ...         ...        ...        ...         ...        ...
# 369  81.559998  152.039993  80.190002  28.240000  102.419998  80.400001
# 370  80.599998  151.570007  79.230003  27.940001  101.620003  80.499997
# 371  81.500000  153.669998  79.970001  28.299999  103.129997  77.069994
# 372  81.059998  154.509995  78.449997  28.150000  103.169998  74.680001
# 373  81.860001  155.729996  81.330002  28.150000  106.699997  76.009997
#
#             DIS         GE          GS          HD  ...        PFE         PG  \
# ...

# %%
f_c
# Out:
#              0
# 0   -50.902404
# 1   -52.846909
# 2   -54.614439
# 3   -52.600566
# 4   -52.370123
# ..         ...
# 369  81.290980
# 370  77.903534
# 371  83.798199
# 372  79.195789
# 373  82.968859
#
# [374 rows x 1 columns]

# %%
f_c.max()
# Out:
# 0    88.953955
# dtype: float64

# %%
a = 0 
for i in pd.DataFrame(f_c):
    if f_c[i]>a:
        a = f_c[i]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-281-cf7bcc3cff9b> in <module>
#       1 a = 0
#       2 for i in pd.DataFrame(f_c):
# ----> 3     if f_c[i]>a:
#       4         a = f_c[i]
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
pca.components_[0]
# Out:
# array([ 1.61383840e-02,  1.20644923e-01, -5.16612711e-02,  5.04842369e-02,
#        -1.25859933e-01,  1.14089567e-01,  2.33906290e-01, -6.20513749e-03,
#         2.51227032e-01,  2.88996029e-01, -2.64998795e-01,  9.31320168e-02,
#         9.13948403e-02,  4.69879340e-02,  2.90549417e-02, -2.61068828e-02,
#         3.29615584e-01,  7.13897133e-02,  7.62295699e-02,  2.11888868e-01,
#         2.30922941e-02,  7.77316954e-02, -7.20594590e-03,  1.89479745e-01,
#         3.21564017e-01,  5.36834873e-02,  5.79683946e-01,  1.09122230e-04,
#         8.71614334e-02, -4.29421420e-02])

# %%
f_c1 = pd.DataFrame(pca.components_[0])

# %%
f_c1 == f_c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-288-ed541667489e> in <module>
# ----> 1 f_c1 == f_c
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other)
#    1565             if not self._indexed_same(other):
#    1566                 raise ValueError(
# -> 1567                     "Can only compare identically-labeled " "DataFrame objects"
#    1568                 )
#    1569             return dispatch_to_series(self, other, func, str_rep)
#
# ValueError: Can only compare identically-labeled DataFrame objects

# %%
f_c
# Out:
#              0
# 0   -50.902404
# 1   -52.846909
# 2   -54.614439
# 3   -52.600566
# 4   -52.370123
# ..         ...
# 369  81.290980
# 370  77.903534
# 371  83.798199
# 372  79.195789
# 373  82.968859
#
# [374 rows x 1 columns]

# %%
df = pd.DataFrame(pca.components_[0])

# %%
df
# Out:
#            0
# 0   0.016138
# 1   0.120645
# 2  -0.051661
# 3   0.050484
# 4  -0.125860
# 5   0.114090
# 6   0.233906
# 7  -0.006205
# 8   0.251227
# 9   0.288996
# 10 -0.264999
# 11  0.093132
# 12  0.091395
# 13  0.046988
# 14  0.029055
# 15 -0.026107
# 16  0.329616
# 17  0.071390
# 18  0.076230
# 19  0.211889
# 20  0.023092
# 21  0.077732
# 22 -0.007206
# 23  0.189480
# 24  0.321564
# 25  0.053683
# 26  0.579684
# 27  0.000109
# 28  0.087161
# 29 -0.042942

# %%
df.max()
# Out:
# 0    0.579684
# dtype: float64

# %%
df
# Out:
#            0
# 0   0.016138
# 1   0.120645
# 2  -0.051661
# 3   0.050484
# 4  -0.125860
# 5   0.114090
# 6   0.233906
# 7  -0.006205
# 8   0.251227
# 9   0.288996
# 10 -0.264999
# 11  0.093132
# 12  0.091395
# 13  0.046988
# 14  0.029055
# 15 -0.026107
# 16  0.329616
# 17  0.071390
# 18  0.076230
# 19  0.211889
# 20  0.023092
# 21  0.077732
# 22 -0.007206
# 23  0.189480
# 24  0.321564
# 25  0.053683
# 26  0.579684
# 27  0.000109
# 28  0.087161
# 29 -0.042942

# %%
df.values
# Out:
# array([[ 1.61383840e-02],
#        [ 1.20644923e-01],
#        [-5.16612711e-02],
#        [ 5.04842369e-02],
#        [-1.25859933e-01],
#        [ 1.14089567e-01],
#        [ 2.33906290e-01],
#        [-6.20513749e-03],
#        [ 2.51227032e-01],
#        [ 2.88996029e-01],
#        [-2.64998795e-01],
#        [ 9.31320168e-02],
#        [ 9.13948403e-02],
#        [ 4.69879340e-02],
#        [ 2.90549417e-02],
#        [-2.61068828e-02],
#        [ 3.29615584e-01],
#        [ 7.13897133e-02],
#        [ 7.62295699e-02],
#        [ 2.11888868e-01],
#        [ 2.30922941e-02],
#        [ 7.77316954e-02],
#        [-7.20594590e-03],
#        [ 1.89479745e-01],
#        [ 3.21564017e-01],
#        [ 5.36834873e-02],
#        [ 5.79683946e-01],
#        [ 1.09122230e-04],
#        [ 8.71614334e-02],
#        [-4.29421420e-02]])

# %%
data_main.columns[26]
# Out:
# 'V'

# %%
indx = -1
value = -1
for i in range(len(pca.components_[0])):
    if value < pca.components_[0][i]:
        value = pca.components_[0][i]
        indx = i
print("Company name: '%s' weight: %0.2f" % (data_main.columns[indx], value))
# Out:
# Company name: 'V' weight: 0.58

# %%
pd
# Out:
# <module 'pandas' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
data = pd.read_csv('abalone.csv')

# %%
data
# Out:
#      Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0      M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1      M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2      F   0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3      M   0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4      I   0.330     0.255   0.080       0.2050         0.0895         0.0395
# ...   ..     ...       ...     ...          ...            ...            ...
# 4172   F   0.565     0.450   0.165       0.8870         0.3700         0.2390
# 4173   M   0.590     0.440   0.135       0.9660         0.4390         0.2145
# 4174   M   0.600     0.475   0.205       1.1760         0.5255         0.2875
# 4175   F   0.625     0.485   0.150       1.0945         0.5310         0.2610
# 4176   M   0.710     0.555   0.195       1.9485         0.9455         0.3765
#
#       ShellWeight  Rings
# ...

# %%
data['Sex'] = data['Sex'].map(lambda x:1 if x=='M'else(-1 if x=='F' else 0))

# %%
data
# Out:
#       Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0       1   0.455     0.365   0.095       0.5140         0.2245
# 1       1   0.350     0.265   0.090       0.2255         0.0995
# 2      -1   0.530     0.420   0.135       0.6770         0.2565
# 3       1   0.440     0.365   0.125       0.5160         0.2155
# 4       0   0.330     0.255   0.080       0.2050         0.0895
# ...   ...     ...       ...     ...          ...            ...
# 4172   -1   0.565     0.450   0.165       0.8870         0.3700
# 4173    1   0.590     0.440   0.135       0.9660         0.4390
# 4174    1   0.600     0.475   0.205       1.1760         0.5255
# 4175   -1   0.625     0.485   0.150       1.0945         0.5310
# 4176    1   0.710     0.555   0.195       1.9485         0.9455
#
#       VisceraWeight  ShellWeight  Rings
# 0            0.1010       0.1500     15
# 1            0.0485       0.0700      7
# 2            0.1415       0.2100      9
# ...

# %%
X, y = data.iloc[:,:8], data.iloc[:,8:]

# %%
X
# Out:
#       Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0       1   0.455     0.365   0.095       0.5140         0.2245
# 1       1   0.350     0.265   0.090       0.2255         0.0995
# 2      -1   0.530     0.420   0.135       0.6770         0.2565
# 3       1   0.440     0.365   0.125       0.5160         0.2155
# 4       0   0.330     0.255   0.080       0.2050         0.0895
# ...   ...     ...       ...     ...          ...            ...
# 4172   -1   0.565     0.450   0.165       0.8870         0.3700
# 4173    1   0.590     0.440   0.135       0.9660         0.4390
# 4174    1   0.600     0.475   0.205       1.1760         0.5255
# 4175   -1   0.625     0.485   0.150       1.0945         0.5310
# 4176    1   0.710     0.555   0.195       1.9485         0.9455
#
#       VisceraWeight  ShellWeight
# 0            0.1010       0.1500
# 1            0.0485       0.0700
# 2            0.1415       0.2100
# 3            0.1140       0.1550
# ...

# %%
import sklearn.ensemble.RandomForestRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-347-1e12b070a1f7> in <module>
# ----> 1 import sklearn.ensemble.RandomForestRegressor
#
# ModuleNotFoundError: No module named 'sklearn.ensemble.RandomForestRegressor'

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
clf = RandomForestRegressor(random_state=1)

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=1)

# %%
kf
# Out:
# KFold(n_splits=5, random_state=1, shuffle=True)

# %%
def r2_scorer(estimator, X, y):
    predictions = estimator.predict(X)
    return r2_score(y, predictions)

# %%
scores = []
for i in range(1,51):
    clf = RandomForestRegressor(random_state=1, n_estimators=i)
    clf.fit(X,y)
    score = cross_val_score(clf, X, y = y, cv = kf, scoring=lambda clf, X, y: r2_score(y, clf.predict(X))).mean()
    scores.append(score)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
for i in enumerate(scores):
    print(np.around(i,4))
# Out:
# [0.     0.1097]
# [1.     0.3413]
# [2.     0.4064]
# [3.     0.4448]
# [4.    0.465]
# [5.     0.4714]
# [6.     0.4767]
# [7.     0.4829]
# [8.     0.4894]
# [9.     0.4954]
# [10.      0.4944]
# [11.     0.499]
# [12.      0.5031]
# [13.      0.5073]
# [14.      0.5092]
# [15.      0.5114]
# [16.      0.5149]
# [17.      0.5172]
# [18.      0.5198]
# [19.      0.5195]
# [20.      0.5205]
# [21.      0.5208]
# [22.      0.5217]
# [23.      0.5231]
# [24.      0.5232]
# [25.      0.5243]
# [26.      0.5246]
# [27.      0.5257]
# [28.      0.5266]
# [29.      0.5271]
# [30.      0.5276]
# [31.      0.5289]
# [32.      0.5301]
# [33.    0.53]
# [34.      0.5298]
# [35.      0.5299]
# [36.      0.5294]
# [37.      0.5295]
# [38.      0.5295]
# [39.      0.5295]
# [40.      0.5298]
# [41.    0.53]
# [42.      0.5299]
# [43.      0.5297]
# [44.      0.5289]
# [45.     0.529]
# [46.      0.5292]
# [47.      0.5301]
# [48.      0.5308]
# [49.     0.531]
